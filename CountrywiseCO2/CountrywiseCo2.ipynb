# %%
import pandas as pd
co2data = pd.read_csv("./Co2Data.csv", index_col = "Country Name")
co2data = co2data.loc["Afghanistan":"Zimbabwe", "1990":"2012"]
co2data = co2data.dropna()
co2data.head()
# Out:
#                        1990           1991           1992           1993  \
# Country Name
# Afghanistan     2614.571000    2438.555000    1393.460000    1345.789000
# Angola          5115.465000    5089.796000    5196.139000    5775.525000
# Albania         5515.168000    4286.723000    2515.562000    2335.879000
# Andorra          407.037000     407.037000     407.037000     410.704000
# Arab World    671736.062165  740323.235533  795658.904745  877890.137902
#
#                        1994           1995           1996        1997  \
# Country Name
# Afghanistan     1294.451000    1243.113000    1177.107000    1096.433
# Angola          3890.687000   10975.331000   10458.284000    7381.671
# Albania         1925.175000    2086.523000    2016.850000    1543.807
# Andorra          407.037000     425.372000     454.708000     465.709
# Arab World    901869.050185  866641.768095  862033.825343  833006.721
#
#                     1998        1999     ...              2003         2004  \
# Country Name                             ...
# Afghanistan     1041.428     821.408     ...          1195.442      949.753
# Angola          7308.331    9156.499     ...          9064.824    18793.375
# Albania         1752.826    2984.938     ...          4294.057     4165.712
# Andorra          491.378     513.380     ...           535.382      561.051
# Arab World    906420.061  919932.956     ...       1143168.915  1252559.192
#
#                      2005         2006         2007         2008         2009  \
# Country Name
# Afghanistan      1327.454     1650.150     2273.540     4206.049     6769.282
# Angola          19156.408    22266.024    25151.953    25709.337    27792.193
# Albania          4253.720     3898.021     3927.357     4374.731     4378.398
# Andorra           575.719      546.383      539.049      539.049      517.047
# Arab World    1318345.172  1381941.953  1359855.612  1491970.288  1581327.744
#
#                      2010         2011         2012
# Country Name
# Afghanistan      8463.436    12240.446    10755.311
# Angola          29057.308    30340.758    33399.036
# Albania          4598.418     5240.143     4910.113
# Andorra           517.047      491.378      487.711
# Arab World    1645558.916  1655808.181  1796962.012
#
# [5 rows x 23 columns]

# %%
co2data["totalEmission"] = (co2data.sum(axis=1)/1000)
cos2data = co2data.sort_values(by=['totalEmission'], inplace=True, ascending=False)
co2data = co2data[10:]
print (co2data.shape)
co2data.head()
# Out:
# (203, 24)
#                                                      1990          1991  \
# Country Name
# East Asia & Pacific                          4.703785e+06  4.912997e+06
# North America                                5.259087e+06  5.248166e+06
# East Asia & Pacific (excluding high income)  2.864275e+06  3.045420e+06
# East Asia & Pacific (IDA & IBRD countries)   2.822276e+06  3.000750e+06
# United States                                4.823403e+06  4.820847e+06
#
#                                                      1992          1993  \
# Country Name
# East Asia & Pacific                          5.156987e+06  5.447900e+06
# North America                                5.350974e+06  5.474794e+06
# East Asia & Pacific (excluding high income)  3.216890e+06  3.457280e+06
# East Asia & Pacific (IDA & IBRD countries)   3.169692e+06  3.406537e+06
# United States                                4.909534e+06  5.028674e+06
#
#                                                      1994          1995  \
# Country Name
# East Asia & Pacific                          5.758134e+06  6.122093e+06
# North America                                5.551735e+06  5.601089e+06
# East Asia & Pacific (excluding high income)  3.667655e+06  3.996722e+06
# East Asia & Pacific (IDA & IBRD countries)   3.613810e+06  3.938025e+06
# United States                                5.094354e+06  5.132920e+06
#
#                                                      1996          1997  \
# Country Name
# East Asia & Pacific                          6.413087e+06  6.523428e+06
# North America                                5.732060e+06  5.864534e+06
# East Asia & Pacific (excluding high income)  4.202091e+06  4.259611e+06
# East Asia & Pacific (IDA & IBRD countries)   4.140366e+06  4.197041e+06
# United States                                5.252112e+06  5.368715e+06
#
#                                                      1998          1999  \
# Country Name
# East Asia & Pacific                          6.184239e+06  6.313362e+06
# North America                                5.908065e+06  6.020572e+06
# East Asia & Pacific (excluding high income)  4.016009e+06  4.049087e+06
# East Asia & Pacific (IDA & IBRD countries)   3.957031e+06  3.984700e+06
# United States                                5.401011e+06  5.504669e+06
#
#                                                  ...                2004  \
# Country Name                                     ...
# East Asia & Pacific                              ...        8.716017e+06
# North America                                    ...        6.308857e+06
# East Asia & Pacific (excluding high income)      ...        6.246987e+06
# East Asia & Pacific (IDA & IBRD countries)       ...        6.174733e+06
# United States                                    ...        5.756075e+06
#
#                                                      2005          2006  \
# Country Name
# East Asia & Pacific                          9.373914e+06  1.002901e+07
# North America                                6.347727e+06  6.241758e+06
# East Asia & Pacific (excluding high income)  6.940456e+06  7.575023e+06
# East Asia & Pacific (IDA & IBRD countries)   6.864976e+06  7.498205e+06
# United States                                5.789727e+06  5.697286e+06
#
#                                                      2007          2008  \
# Country Name
# East Asia & Pacific                          1.063488e+07  1.122486e+07
# North America                                6.344115e+06  6.175789e+06
# East Asia & Pacific (excluding high income)  8.122758e+06  8.727787e+06
# East Asia & Pacific (IDA & IBRD countries)   8.058596e+06  8.656698e+06
# United States                                5.789031e+06  5.614111e+06
#
#                                                      2009          2010  \
# Country Name
# East Asia & Pacific                          1.163108e+07  1.258472e+07
# North America                                5.800747e+06  5.930811e+06
# East Asia & Pacific (excluding high income)  9.227347e+06  1.003967e+07
# East Asia & Pacific (IDA & IBRD countries)   9.156693e+06  9.973224e+06
# United States                                5.263505e+06  5.395532e+06
#
#                                                      2011          2012  \
# Country Name
# East Asia & Pacific                          1.375383e+07  1.410949e+07
# North America                                5.827237e+06  5.637371e+06
# East Asia & Pacific (excluding high income)  1.117215e+07  1.151557e+07
# East Asia & Pacific (IDA & IBRD countries)   1.112410e+07  1.146649e+07
# United States                                5.289681e+06  5.119436e+06
#
#                                              totalEmission
# Country Name
# East Asia & Pacific                          187856.237321
# North America                                135368.889144
# East Asia & Pacific (excluding high income)  135107.560362
# East Asia & Pacific (IDA & IBRD countries)   133687.405682
# United States                                123657.114534
#
# [5 rows x 24 columns]

# %%
xValues = co2data.index.tolist()
yValues = []

for index in xValues:
    yValues.append(co2data.loc[index]["totalEmission"])

print (len(yValues), len(xValues))
# Out:
# 203 203

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure('Country-wise Co2 emission')
plt.plot(xValues, yValues)
# x_axis = np.arange(mu-z*np.sqrt(sig2), mu+z*np.sqrt(sig2), 1)
y_axis = np.arange(0, 200000, 50000)
plt.xticks(xValues)
plt.yticks(y_axis)
plt.xlabel('x')
plt.ylabel('CO2 emission')
plt.title('Country-wise Co2 emission')
plt.show()

# %%
import scipy.stats
import math

a, m = 1., float(min(yValues))
s = (np.random.pareto(a, 1000) + 1) * m
p,q = len(s), len(yValues)
print(math.sqrt((p+q)/p*q))
print(scipy.stats.ks_2samp(s, yValues)) #check the score
# Out:
# 15.627187846826441
# Ks_2sampResult(statistic=0.8788866995073891, pvalue=6.822041238669651e-116)

# %%
a, m = 5., 2.
s = (np.random.pareto(a, 1000) + 1) * m
count, bins, _ = plt.hist(s, 100, normed=True)
fit = a*m**a / bins**(a+1)
plt.plot(bins, max(count)*fit/max(fit), linewidth=2, color='r')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
minVal = min(yValues)
sumVal = 0

numerator = len(yValues)
denominator = sum([np.log(x) for x in yValues]) + len(yValues)*minVal

mle_alpha = numerator/denominator
print ((mle_alpha))
# Out:
# 0.1686175303066068
